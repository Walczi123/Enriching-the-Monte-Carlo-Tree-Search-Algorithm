# %% [markdown]
# ### Results  - Hex

# %%
from data_processing import *

# %%
SEPARATHOR = ','
XLSX_FILE_NAME = 'hex_results.xlsx'
# FILE_PATH = '../finished_tests/prarameters_tests/hex_othello_results_param_test.csv'
# FILE_PATH = '../finished_tests/final_tests.csv'
FILE_PATH = '../finished_tests/copy_final_test_part2_0.1.csv'

# %%
df = read_data_of_game(FILE_PATH, SEPARATHOR, 'hex')
result_df = check_data_and_create_result_df(df, True) #False
df_tournament = create_tournament_df(df, list(result_df.index))
# Out:
# Amount data before check: 597
# Amount data after check: 597

# %%
result_df[:6]
# Out:
#                                                     wins  draws  defeats  \
# mcts10000                                            177      0       23
# mctsstrategies10000(random_strategy:mobility_st...   145      0       55
# alphabeta10                                          132      0       68
# alphabeta12                                          132      0       68
# mctsstrategy10000(mobility_strategy)                 131      0       69
# mctsstrategy10000(mobility_strategy_vs)              108      0       91
#
#                                                     avg game time  score  \
# mcts10000                                                16486.09  177.0
# mctsstrategies10000(random_strategy:mobility_st...       66643.05  145.0
# alphabeta10                                              23557.72  132.0
# alphabeta12                                              22688.47  132.0
# mctsstrategy10000(mobility_strategy)                     71138.40  131.0
# mctsstrategy10000(mobility_strategy_vs)                 113331.81  108.0
#
#                                                          win%  draws%  \
# mcts10000                                           88.500000     0.0
# mctsstrategies10000(random_strategy:mobility_st...  72.500000     0.0
# alphabeta10                                         66.000000     0.0
# alphabeta12                                         66.000000     0.0
# mctsstrategy10000(mobility_strategy)                65.500000     0.0
# mctsstrategy10000(mobility_strategy_vs)             54.271357     0.0
#
#                                                      defeats%  no games
# mcts10000                                           11.500000       200
# mctsstrategies10000(random_strategy:mobility_st...  27.500000       200
# alphabeta10                                         34.000000       200
# alphabeta12                                         34.000000       200
# mctsstrategy10000(mobility_strategy)                34.500000       200
# mctsstrategy10000(mobility_strategy_vs)             45.728643       199

# %%
df_tournament.iloc[:6,:6]
# Out:
#                                                    mcts10000  \
# mcts10000                                              3-0-7
# mctsstrategies10000(random_strategy:mobility_st...     1-0-9
# alphabeta10                                            5-0-5
# alphabeta12                                            5-0-5
# mctsstrategy10000(mobility_strategy)                  0-0-10
# mctsstrategy10000(mobility_strategy_vs)               0-0-10
#
#                                                    mctsstrategies10000(random_strategy:mobility_strategy_vs:mobility_strategy:evaluatehex_strategy)  \
# mcts10000                                                                                       9-0-1
# mctsstrategies10000(random_strategy:mobility_st...                                              5-0-5
# alphabeta10                                                                                     6-0-4
# alphabeta12                                                                                     6-0-4
# mctsstrategy10000(mobility_strategy)                                                            4-0-6
# mctsstrategy10000(mobility_strategy_vs)                                                         1-0-9
#
#                                                    alphabeta10 alphabeta12  \
# mcts10000                                               10-0-0      10-0-0
# mctsstrategies10000(random_strategy:mobility_st...       9-0-1       9-0-1
# alphabeta10                                             0-0-10      0-0-10
# alphabeta12                                             0-0-10      0-0-10
# mctsstrategy10000(mobility_strategy)                     6-0-4       6-0-4
# mctsstrategy10000(mobility_strategy_vs)                 0-0-10      0-0-10
#
#                                                    mctsstrategy10000(mobility_strategy)  \
# mcts10000                                                                        10-0-0
# mctsstrategies10000(random_strategy:mobility_st...                                9-0-1
# alphabeta10                                                                       2-0-8
# alphabeta12                                                                       2-0-8
# mctsstrategy10000(mobility_strategy)                                              3-0-7
# mctsstrategy10000(mobility_strategy_vs)                                           5-0-5
#
#                                                    mctsstrategy10000(mobility_strategy_vs)
# mcts10000                                                                            9-0-1
# mctsstrategies10000(random_strategy:mobility_st...                                   3-0-7
# alphabeta10                                                                          4-0-6
# alphabeta12                                                                          4-0-6
# mctsstrategy10000(mobility_strategy)                                                 3-0-7
# mctsstrategy10000(mobility_strategy_vs)                                              2-0-8

# %%
writer = pd.ExcelWriter(XLSX_FILE_NAME, engine='xlsxwriter')
result_df.to_excel(writer, sheet_name='result_df')
df_tournament.to_excel(writer, sheet_name='df_tournament')
writer.save()
